# %% [markdown]
# <a href="https://colab.research.google.com/github/sparkychem/my-first-repo/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/octosport/octopy.git
# Out:
# ...
#   Cloning https://github.com/octosport/octopy.git to /tmp/pip-req-build-umm15ciw
#   Running command git clone -q https://github.com/octosport/octopy.git /tmp/pip-req-build-umm15ciw
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3f8fc195-fb37-415b-95be-f84a92db9256" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3f8fc195-fb37-415b-95be-f84a92db9256">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving results.csv to results (1).csv

# %%
import pandas as pd
import datetime
import matplotlib.pyplot as plt
from octopy.elo import dataset
from octopy.elo import elo
import io

#get the data
data = pd.read_csv(io.BytesIO(uploaded['results.csv']))

#format the data
elo_data = dataset.EloDataset(valid_date= '2020-06-01',test_date= '2021-06-01',time= data['date'])

#split the data
elo_data.split_train_test(data[['home','away']].values,data[['home_goals','away_goals']].values)

#build the model and train
model = elo.EloRatingNet(elo_data.n_teams_)
model.optimise(elo_data,learning_rate=0.075)
# Out:
# dataset split using date: train size 41771, validation size 506, test size 1138
#   0%|          | 0/10000 [00:00<?, ?it/s]
# train_loss: 1.0140, valid_loss: 1.0085, test_loss: 0.9406
# train_loss: 0.9579, valid_loss: 0.9276, test_loss: 0.8664
# train_loss: 0.9578, valid_loss: 0.9273, test_loss: 0.8662

# %%
last_rating = pd.DataFrame(model.output_['carry']['rating'],index=elo_data.le_.classes_,columns=['last rating']) .sort_values('last rating',ascending=False)
last_rating

# %% [markdown]
# **UNTUK 2 TIM**
#
#
# ---

# %%
TeamName1 = 'Curaçao'
TeamName2 = 'Guatemala'

score = pd.Series(model.predict_proba(TeamName1,TeamName2))
from random import choices
population = [TeamName1+" Win", TeamName1 + ' dan ' + TeamName2 + ' seri', TeamName2+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match1 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName2,TeamName1))
from random import choices
population = [TeamName2+" Win", TeamName2 + ' dan ' + TeamName1 + ' seri', TeamName1+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match2 = choices(population, weights)

print(match1)
print(match2)

# %% [markdown]
# **UNTUK 3 TIM**
#
#
# ---

# %%
TeamName1 = 'Japan'
TeamName2 = 'Palestine'
TeamName3 = 'Indonesia'

score = pd.Series(model.predict_proba(TeamName1,TeamName2))
from random import choices
population = [TeamName1+" Win", TeamName1 + ' dan ' + TeamName2 + ' seri', TeamName2+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match1 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName2,TeamName1))
from random import choices
population = [TeamName2+" Win", TeamName2 + ' dan ' + TeamName1 + ' seri', TeamName1+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match2 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName1,TeamName3))
from random import choices
population = [TeamName1+" Win", TeamName1 + ' dan ' + TeamName3 + ' seri', TeamName3+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match3 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName3,TeamName1))
from random import choices
population = [TeamName3+" Win", TeamName3 + ' dan ' + TeamName1 + ' seri', TeamName1+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match4 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName2,TeamName3))
from random import choices
population = [TeamName2+" Win", TeamName2 + ' dan ' + TeamName3 + ' seri', TeamName3+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match5 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName3,TeamName2))
from random import choices
population = [TeamName3+" Win", TeamName3 + ' dan ' + TeamName2 + ' seri', TeamName2+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match6 = choices(population, weights)

print(match1)
print(match2)
print(match3)
print(match4)
print(match5)
print(match6)

# %% [markdown]
# **UNTUK 4 TIM**
#
#
# ---

# %%
TeamName1 = 'Ivory Coast'
TeamName2 = 'Tunisia'
TeamName3 = 'Nigeria'
TeamName4 = 'Malawi'

score = pd.Series(model.predict_proba(TeamName1,TeamName2))
from random import choices
population = [TeamName1+" Win", TeamName1 + ' dan ' + TeamName2 + ' seri', TeamName2+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match1 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName2,TeamName1))
from random import choices
population = [TeamName2+" Win", TeamName2 + ' dan ' + TeamName1 + ' seri', TeamName1+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match2 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName1,TeamName3))
from random import choices
population = [TeamName1+" Win", TeamName1 + ' dan ' + TeamName3 + ' seri', TeamName3+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match3 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName3,TeamName1))
from random import choices
population = [TeamName3+" Win", TeamName3 + ' dan ' + TeamName1 + ' seri', TeamName1+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match4 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName1,TeamName4))
from random import choices
population = [TeamName1+" Win", TeamName1 + ' dan ' + TeamName4 + ' seri', TeamName4+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match5 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName4,TeamName1))
from random import choices
population = [TeamName4+" Win", TeamName4 + ' dan ' + TeamName1 + ' seri', TeamName1+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match6 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName2,TeamName3))
from random import choices
population = [TeamName2+" Win", TeamName2 + ' dan ' + TeamName3 + ' seri', TeamName3+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match7 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName3,TeamName2))
from random import choices
population = [TeamName3+" Win", TeamName3 + ' dan ' + TeamName2 + ' seri', TeamName2+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match8 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName2,TeamName4))
from random import choices
population = [TeamName2+" Win", TeamName2 + ' dan ' + TeamName4 + ' seri', TeamName4+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match9 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName4,TeamName2))
from random import choices
population = [TeamName4+" Win", TeamName4 + ' dan ' + TeamName2 + ' seri', TeamName2+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match10 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName3,TeamName4))
from random import choices
population = [TeamName3+" Win", TeamName3 + ' dan ' + TeamName4 + ' seri', TeamName4+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match11 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName4,TeamName3))
from random import choices
population = [TeamName4+" Win", TeamName4 + ' dan ' + TeamName3 + ' seri', TeamName3+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match12 = choices(population, weights)

print(match1)
print(match2)
print(match3)
print(match4)
print(match5)
print(match6)
print(match7)
print(match8)
print(match9)
print(match10)
print(match11)
print(match12)

shortlist = [(match1),
             (match2),
             (match3),
             (match4),
             (match5),
             (match6),
             (match7),
             (match8),
             (match9),
             (match10),
             (match11),
             (match12)]

win1 = shortlist.count([TeamName1+" Win"])
print("Jumlah Kemenangan " + TeamName1 + " adalah " + str(win1))

win2 = shortlist.count([TeamName2+" Win"])
print("Jumlah Kemenangan " + TeamName2 + " adalah " + str(win2))

win3 = shortlist.count([TeamName3+" Win"])
print("Jumlah Kemenangan " + TeamName3 + " adalah " + str(win3))

win4 = shortlist.count([TeamName4+" Win"])
print("Jumlah Kemenangan " + TeamName4 + " adalah " + str(win4))

# %% [markdown]
# **UNTUK 5 TIM**
#
#
# ---

# %%
TeamName1 = 'Haiti'
TeamName2 = 'Nicaragua'
TeamName3 = 'Barbados'
TeamName4 = 'Dominica'
TeamName5 = 'British Virgin Islands'

score = pd.Series(model.predict_proba(TeamName1,TeamName4))
from random import choices
population = [TeamName1+" Win", TeamName1 + ' dan ' + TeamName4 + ' seri', TeamName4+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match1 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName4,TeamName1))
from random import choices
population = [TeamName4+" Win", TeamName4 + ' dan ' + TeamName1 + ' seri', TeamName1+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match2 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName2,TeamName3))
from random import choices
population = [TeamName2+" Win", TeamName2 + ' dan ' + TeamName3 + ' seri', TeamName3+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match3 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName3,TeamName2))
from random import choices
population = [TeamName3+" Win", TeamName3 + ' dan ' + TeamName2 + ' seri', TeamName2+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match4 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName3,TeamName1))
from random import choices
population = [TeamName3+" Win", TeamName3 + ' dan ' + TeamName1 + ' seri', TeamName1+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match5 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName1,TeamName3))
from random import choices
population = [TeamName1+" Win", TeamName1 + ' dan ' + TeamName3 + ' seri', TeamName3+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match6 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName4,TeamName5))
from random import choices
population = [TeamName4+" Win", TeamName4 + ' dan ' + TeamName5 + ' seri', TeamName5+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match7 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName5,TeamName4))
from random import choices
population = [TeamName5+" Win", TeamName5 + ' dan ' + TeamName4 + ' seri', TeamName4+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match8 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName5,TeamName3))
from random import choices
population = [TeamName5+" Win", TeamName5 + ' dan ' + TeamName3 + ' seri', TeamName3+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match9 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName3,TeamName5))
from random import choices
population = [TeamName3+" Win", TeamName3 + ' dan ' + TeamName5 + ' seri', TeamName5+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match10 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName1,TeamName2))
from random import choices
population = [TeamName1+" Win", TeamName1 + ' dan ' + TeamName2 + ' seri', TeamName2+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match11 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName2,TeamName1))
from random import choices
population = [TeamName2+" Win", TeamName2 + ' dan ' + TeamName1 + ' seri', TeamName1+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match12 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName2,TeamName5))
from random import choices
population = [TeamName2+" Win", TeamName2 + ' dan ' + TeamName5 + ' seri', TeamName5+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match13 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName5,TeamName2))
from random import choices
population = [TeamName5+" Win", TeamName5 + ' dan ' + TeamName2 + ' seri', TeamName2+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match14 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName3,TeamName4))
from random import choices
population = [TeamName3+" Win", TeamName3 + ' dan ' + TeamName4 + ' seri', TeamName4+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match15 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName4,TeamName3))
from random import choices
population = [TeamName4+" Win", TeamName4 + ' dan ' + TeamName3 + ' seri', TeamName3+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match16 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName4,TeamName2))
from random import choices
population = [TeamName4+" Win", TeamName4 + ' dan ' + TeamName2 + ' seri', TeamName2+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match17 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName2,TeamName4))
from random import choices
population = [TeamName2+" Win", TeamName2 + ' dan ' + TeamName4 + ' seri', TeamName4+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match18 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName5,TeamName1))
from random import choices
population = [TeamName5+" Win", TeamName5 + ' dan ' + TeamName1 + ' seri', TeamName1+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match19 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName1,TeamName5))
from random import choices
population = [TeamName1+" Win", TeamName1 + ' dan ' + TeamName5 + ' seri', TeamName5+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match20 = choices(population, weights)

print(match1)
print(match2)
print(match3)
print(match4)
print(match5)
print(match6)
print(match7)
print(match8)
print(match9)
print(match10)
print(match11)
print(match12)
print(match13)
print(match14)
print(match15)
print(match16)
print(match17)
print(match18)
print(match19)
print(match20)

shortlist = [(match1),
             (match2),
             (match3),
             (match4),
             (match5),
             (match6),
             (match7),
             (match8),
             (match9),
             (match10),
             (match11),
             (match12),
             (match13),
             (match14),
             (match15),
             (match16),
             (match17),
             (match18),
             (match19),
             (match20)]

win1 = shortlist.count([TeamName1+" Win"])
print("Jumlah Kemenangan " + TeamName1 + " adalah " + str(win1))

win2 = shortlist.count([TeamName2+" Win"])
print("Jumlah Kemenangan " + TeamName2 + " adalah " + str(win2))

win3 = shortlist.count([TeamName3+" Win"])
print("Jumlah Kemenangan " + TeamName3 + " adalah " + str(win3))

win4 = shortlist.count([TeamName4+" Win"])
print("Jumlah Kemenangan " + TeamName4 + " adalah " + str(win4))

win5 = shortlist.count([TeamName5+" Win"])
print("Jumlah Kemenangan " + TeamName5 + " adalah " + str(win5))

# %% [markdown]
# **UNTUK 6 TIM**
#
#
# ---

# %%
TeamName1 = 'Japan'
TeamName2 = 'Palestine'
TeamName3 = 'Indonesia'
TeamName4 = 'Bahrain'
TeamName5 = 'Saudi Arabia'
TeamName6 = 'Brazil'

score = pd.Series(model.predict_proba(TeamName1,TeamName4))
from random import choices
population = [TeamName1+" Win", TeamName1 + ' dan ' + TeamName4 + ' seri', TeamName4+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match1 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName4,TeamName1))
from random import choices
population = [TeamName4+" Win", TeamName4 + ' dan ' + TeamName1 + ' seri', TeamName1+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match2 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName2,TeamName3))
from random import choices
population = [TeamName2+" Win", TeamName2 + ' dan ' + TeamName3 + ' seri', TeamName3+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match3 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName3,TeamName2))
from random import choices
population = [TeamName3+" Win", TeamName3 + ' dan ' + TeamName2 + ' seri', TeamName2+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match4 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName3,TeamName1))
from random import choices
population = [TeamName3+" Win", TeamName3 + ' dan ' + TeamName1 + ' seri', TeamName1+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match5 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName1,TeamName3))
from random import choices
population = [TeamName1+" Win", TeamName1 + ' dan ' + TeamName3 + ' seri', TeamName3+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match6 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName4,TeamName5))
from random import choices
population = [TeamName4+" Win", TeamName4 + ' dan ' + TeamName5 + ' seri', TeamName5+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match7 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName5,TeamName4))
from random import choices
population = [TeamName5+" Win", TeamName5 + ' dan ' + TeamName4 + ' seri', TeamName4+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match8 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName5,TeamName3))
from random import choices
population = [TeamName5+" Win", TeamName5 + ' dan ' + TeamName3 + ' seri', TeamName3+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match9 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName3,TeamName5))
from random import choices
population = [TeamName3+" Win", TeamName3 + ' dan ' + TeamName5 + ' seri', TeamName5+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match10 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName1,TeamName2))
from random import choices
population = [TeamName1+" Win", TeamName1 + ' dan ' + TeamName2 + ' seri', TeamName2+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match11 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName2,TeamName1))
from random import choices
population = [TeamName2+" Win", TeamName2 + ' dan ' + TeamName1 + ' seri', TeamName1+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match12 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName2,TeamName5))
from random import choices
population = [TeamName2+" Win", TeamName2 + ' dan ' + TeamName5 + ' seri', TeamName5+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match13 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName5,TeamName2))
from random import choices
population = [TeamName5+" Win", TeamName5 + ' dan ' + TeamName2 + ' seri', TeamName2+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match14 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName3,TeamName4))
from random import choices
population = [TeamName3+" Win", TeamName3 + ' dan ' + TeamName4 + ' seri', TeamName4+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match15 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName4,TeamName3))
from random import choices
population = [TeamName4+" Win", TeamName4 + ' dan ' + TeamName3 + ' seri', TeamName3+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match16 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName4,TeamName2))
from random import choices
population = [TeamName4+" Win", TeamName4 + ' dan ' + TeamName2 + ' seri', TeamName2+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match17 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName2,TeamName4))
from random import choices
population = [TeamName2+" Win", TeamName2 + ' dan ' + TeamName4 + ' seri', TeamName4+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match18 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName5,TeamName1))
from random import choices
population = [TeamName5+" Win", TeamName5 + ' dan ' + TeamName1 + ' seri', TeamName1+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match19 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName1,TeamName5))
from random import choices
population = [TeamName1+" Win", TeamName1 + ' dan ' + TeamName5 + ' seri', TeamName5+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match20 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName1,TeamName6))
from random import choices
population = [TeamName1+" Win", TeamName1 + ' dan ' + TeamName6 + ' seri', TeamName6+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match21 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName6,TeamName1))
from random import choices
population = [TeamName6+" Win", TeamName6 + ' dan ' + TeamName1 + ' seri', TeamName1+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match22 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName2,TeamName6))
from random import choices
population = [TeamName2+" Win", TeamName2 + ' dan ' + TeamName6 + ' seri', TeamName6+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match23 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName6,TeamName2))
from random import choices
population = [TeamName6+" Win", TeamName6 + ' dan ' + TeamName2 + ' seri', TeamName2+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match24 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName3,TeamName6))
from random import choices
population = [TeamName3+" Win", TeamName3 + ' dan ' + TeamName6 + ' seri', TeamName6+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match25 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName6,TeamName3))
from random import choices
population = [TeamName6+" Win", TeamName6 + ' dan ' + TeamName3 + ' seri', TeamName3+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match26 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName4,TeamName6))
from random import choices
population = [TeamName4+" Win", TeamName4 + ' dan ' + TeamName6 + ' seri', TeamName6+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match27 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName6,TeamName4))
from random import choices
population = [TeamName6+" Win", TeamName6 + ' dan ' + TeamName4 + ' seri', TeamName4+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match28 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName5,TeamName6))
from random import choices
population = [TeamName5+" Win", TeamName5 + ' dan ' + TeamName6 + ' seri', TeamName6+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match29 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName6,TeamName5))
from random import choices
population = [TeamName6+" Win", TeamName6 + ' dan ' + TeamName5 + ' seri', TeamName5+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match30 = choices(population, weights)

print(match1)
print(match2)
print(match3)
print(match4)
print(match5)
print(match6)
print(match7)
print(match8)
print(match9)
print(match10)
print(match11)
print(match12)
print(match13)
print(match14)
print(match15)
print(match16)
print(match17)
print(match18)
print(match19)
print(match20)
print(match21)
print(match22)
print(match23)
print(match24)
print(match25)
print(match26)
print(match27)
print(match28)
print(match29)
print(match30)

shortlist = [(match1),
             (match2),
             (match3),
             (match4),
             (match5),
             (match6),
             (match7),
             (match8),
             (match9),
             (match10),
             (match11),
             (match12),
             (match13),
             (match14),
             (match15),
             (match16),
             (match17),
             (match18),
             (match19),
             (match20),
             (match21),
             (match22),
             (match23),
             (match24),
             (match25),
             (match26),
             (match27),
             (match28),
             (match29),
             (match30)]

win1 = shortlist.count([TeamName1+" Win"])
print("Jumlah Kemenangan " + TeamName1 + " adalah " + str(win1))

win2 = shortlist.count([TeamName2+" Win"])
print("Jumlah Kemenangan " + TeamName2 + " adalah " + str(win2))

win3 = shortlist.count([TeamName3+" Win"])
print("Jumlah Kemenangan " + TeamName3 + " adalah " + str(win3))

win4 = shortlist.count([TeamName4+" Win"])
print("Jumlah Kemenangan " + TeamName4 + " adalah " + str(win4))

win5 = shortlist.count([TeamName5+" Win"])
print("Jumlah Kemenangan " + TeamName5 + " adalah " + str(win5))

win6 = shortlist.count([TeamName6+" Win"])
print("Jumlah Kemenangan " + TeamName6 + " adalah " + str(win6))

# %% [markdown]
# **UNTUK 8 TIM (RUNNING 2X)**
#
#
# ---

# %%
TeamName1 = 'Bahrain'
TeamName2 = 'Japan'
TeamName3 = 'Kyrgyzstan'
TeamName4 = 'China PR'
TeamName5 = 'Syria'
TeamName6 = 'Uzbekistan'
TeamName7 = 'Jordan'
TeamName8 = 'Oman'

score = pd.Series(model.predict_proba(TeamName1,TeamName2))
from random import choices
population = [TeamName1+" Win", TeamName1 + ' dan ' + TeamName2 + ' seri', TeamName2+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match1 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName1,TeamName3))
from random import choices
population = [TeamName1+" Win", TeamName1 + ' dan ' + TeamName3 + ' seri', TeamName3+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match2 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName1,TeamName4))
from random import choices
population = [TeamName1+" Win", TeamName1 + ' dan ' + TeamName4 + ' seri', TeamName4+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match3 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName1,TeamName5))
from random import choices
population = [TeamName1+" Win", TeamName1 + ' dan ' + TeamName5 + ' seri', TeamName5+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match4 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName1,TeamName6))
from random import choices
population = [TeamName1+" Win", TeamName1 + ' dan ' + TeamName6 + ' seri', TeamName6+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match5 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName1,TeamName7))
from random import choices
population = [TeamName1+" Win", TeamName1 + ' dan ' + TeamName7 + ' seri', TeamName7+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match6 = choices(population, weights)


score = pd.Series(model.predict_proba(TeamName2,TeamName3))
from random import choices
population = [TeamName2+" Win", TeamName2 + ' dan ' + TeamName3 + ' seri', TeamName3+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match7 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName2,TeamName4))
from random import choices
population = [TeamName2+" Win", TeamName2 + ' dan ' + TeamName4 + ' seri', TeamName4+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match8 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName2,TeamName5))
from random import choices
population = [TeamName2+" Win", TeamName2 + ' dan ' + TeamName5 + ' seri', TeamName5+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match9 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName2,TeamName6))
from random import choices
population = [TeamName2+" Win", TeamName2 + ' dan ' + TeamName6 + ' seri', TeamName6+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match10 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName2,TeamName7))
from random import choices
population = [TeamName2+" Win", TeamName2 + ' dan ' + TeamName7 + ' seri', TeamName7+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match11 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName3,TeamName4))
from random import choices
population = [TeamName3+" Win", TeamName3 + ' dan ' + TeamName4 + ' seri', TeamName4+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match12 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName3,TeamName5))
from random import choices
population = [TeamName3+" Win", TeamName3 + ' dan ' + TeamName5 + ' seri', TeamName5+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match13 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName3,TeamName6))
from random import choices
population = [TeamName3+" Win", TeamName3 + ' dan ' + TeamName6 + ' seri', TeamName6+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match14 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName3,TeamName7))
from random import choices
population = [TeamName3+" Win", TeamName3 + ' dan ' + TeamName7 + ' seri', TeamName7+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match15 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName4,TeamName5))
from random import choices
population = [TeamName4+" Win", TeamName4 + ' dan ' + TeamName5 + ' seri', TeamName5+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match16 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName4,TeamName6))
from random import choices
population = [TeamName4+" Win", TeamName4 + ' dan ' + TeamName6 + ' seri', TeamName6+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match17 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName4,TeamName7))
from random import choices
population = [TeamName4+" Win", TeamName4 + ' dan ' + TeamName7 + ' seri', TeamName7+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match18 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName5,TeamName6))
from random import choices
population = [TeamName5+" Win", TeamName5 + ' dan ' + TeamName6 + ' seri', TeamName6+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match19 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName5,TeamName7))
from random import choices
population = [TeamName5+" Win", TeamName5 + ' dan ' + TeamName7 + ' seri', TeamName7+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match20 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName6,TeamName7))
from random import choices
population = [TeamName6+" Win", TeamName6 + ' dan ' + TeamName7 + ' seri', TeamName7+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match21 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName1,TeamName8))
from random import choices
population = [TeamName1+" Win", TeamName1 + ' dan ' + TeamName8 + ' seri', TeamName8+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match22 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName2,TeamName8))
from random import choices
population = [TeamName2+" Win", TeamName2 + ' dan ' + TeamName8 + ' seri', TeamName8+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match23 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName3,TeamName8))
from random import choices
population = [TeamName3+" Win", TeamName3 + ' dan ' + TeamName8 + ' seri', TeamName8+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match24 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName4,TeamName8))
from random import choices
population = [TeamName4+" Win", TeamName4 + ' dan ' + TeamName8 + ' seri', TeamName8+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match25 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName5,TeamName8))
from random import choices
population = [TeamName5+" Win", TeamName5 + ' dan ' + TeamName8 + ' seri', TeamName8+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match26 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName6,TeamName8))
from random import choices
population = [TeamName6+" Win", TeamName6 + ' dan ' + TeamName8 + ' seri', TeamName8+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match27 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName7,TeamName8))
from random import choices
population = [TeamName7+" Win", TeamName7 + ' dan ' + TeamName8 + ' seri', TeamName8+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match28 = choices(population, weights)


print(match1)
print(match2)
print(match3)
print(match4)
print(match5)
print(match6)
print(match7)
print(match8)
print(match9)
print(match10)
print(match11)
print(match12)
print(match13)
print(match14)
print(match15)
print(match16)
print(match17)
print(match18)
print(match19)
print(match20)
print(match21)
print(match22)
print(match23)
print(match24)
print(match25)
print(match26)
print(match27)
print(match28)


shortlist = [(match1),
             (match2),
             (match3),
             (match4),
             (match5),
             (match6),
             (match7),
             (match8),
             (match9),
             (match10),
             (match11),
             (match12),
             (match13),
             (match14),
             (match15),
             (match16),
             (match17),
             (match18),
             (match19),
             (match20),
             (match21),
             (match22),
             (match23),
             (match24),
             (match25),
             (match26),
             (match27),
             (match28)]

win1 = shortlist.count([TeamName1+" Win"])
print("Jumlah Kemenangan " + TeamName1 + " adalah " + str(win1))

win2 = shortlist.count([TeamName2+" Win"])
print("Jumlah Kemenangan " + TeamName2 + " adalah " + str(win2))

win3 = shortlist.count([TeamName3+" Win"])
print("Jumlah Kemenangan " + TeamName3 + " adalah " + str(win3))

win4 = shortlist.count([TeamName4+" Win"])
print("Jumlah Kemenangan " + TeamName4 + " adalah " + str(win4))

win5 = shortlist.count([TeamName5+" Win"])
print("Jumlah Kemenangan " + TeamName5 + " adalah " + str(win5))

win6 = shortlist.count([TeamName6+" Win"])
print("Jumlah Kemenangan " + TeamName6 + " adalah " + str(win6))

win7 = shortlist.count([TeamName7+" Win"])
print("Jumlah Kemenangan " + TeamName7 + " adalah " + str(win7))

win8 = shortlist.count([TeamName8+" Win"])
print("Jumlah Kemenangan " + TeamName8 + " adalah " + str(win8))

# %% [markdown]
# **UNTUK 10 TIM (RUNNING 2X)**
#
# ---

# %%
TeamName1 = 'Japan'
TeamName2 = 'Palestine'
TeamName3 = 'Indonesia'
TeamName4 = 'Bahrain'
TeamName5 = 'Saudi Arabia'
TeamName6 = 'Brazil'
TeamName7 = 'Germany'
TeamName8 = 'Russia'
TeamName9 = 'Italy'
TeamName10 = 'Belgium'

score = pd.Series(model.predict_proba(TeamName1,TeamName2))
from random import choices
population = [TeamName1+" Win", TeamName1 + ' dan ' + TeamName2 + ' seri', TeamName2+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match1 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName1,TeamName3))
from random import choices
population = [TeamName1+" Win", TeamName1 + ' dan ' + TeamName3 + ' seri', TeamName3+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match2 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName1,TeamName4))
from random import choices
population = [TeamName1+" Win", TeamName1 + ' dan ' + TeamName4 + ' seri', TeamName4+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match3 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName1,TeamName5))
from random import choices
population = [TeamName1+" Win", TeamName1 + ' dan ' + TeamName5 + ' seri', TeamName5+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match4 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName1,TeamName6))
from random import choices
population = [TeamName1+" Win", TeamName1 + ' dan ' + TeamName6 + ' seri', TeamName6+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match5 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName1,TeamName7))
from random import choices
population = [TeamName1+" Win", TeamName1 + ' dan ' + TeamName7 + ' seri', TeamName7+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match6 = choices(population, weights)


score = pd.Series(model.predict_proba(TeamName1,TeamName8))
from random import choices
population = [TeamName1+" Win", TeamName1 + ' dan ' + TeamName8 + ' seri', TeamName8+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match7 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName1,TeamName9))
from random import choices
population = [TeamName1+" Win", TeamName1 + ' dan ' + TeamName9 + ' seri', TeamName9+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match8 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName1,TeamName10))
from random import choices
population = [TeamName1+" Win", TeamName10 + ' dan ' + TeamName10 + ' seri', TeamName10+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match9 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName2,TeamName3))
from random import choices
population = [TeamName2+" Win", TeamName2 + ' dan ' + TeamName3 + ' seri', TeamName3+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match10 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName2,TeamName4))
from random import choices
population = [TeamName2+" Win", TeamName2 + ' dan ' + TeamName4 + ' seri', TeamName4+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match11 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName2,TeamName5))
from random import choices
population = [TeamName2+" Win", TeamName2 + ' dan ' + TeamName5 + ' seri', TeamName5+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match12 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName2,TeamName6))
from random import choices
population = [TeamName2+" Win", TeamName2 + ' dan ' + TeamName6 + ' seri', TeamName6+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match13 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName2,TeamName7))
from random import choices
population = [TeamName2+" Win", TeamName2 + ' dan ' + TeamName7 + ' seri', TeamName7+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match14 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName2,TeamName8))
from random import choices
population = [TeamName2+" Win", TeamName2 + ' dan ' + TeamName8 + ' seri', TeamName8+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match15 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName2,TeamName9))
from random import choices
population = [TeamName2+" Win", TeamName2 + ' dan ' + TeamName9 + ' seri', TeamName9+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match16 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName2,TeamName10))
from random import choices
population = [TeamName2+" Win", TeamName2 + ' dan ' + TeamName10 + ' seri', TeamName10+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match17 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName3,TeamName4))
from random import choices
population = [TeamName3+" Win", TeamName3 + ' dan ' + TeamName4 + ' seri', TeamName4+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match18 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName3,TeamName5))
from random import choices
population = [TeamName3+" Win", TeamName3 + ' dan ' + TeamName5 + ' seri', TeamName5+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match19 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName3,TeamName6))
from random import choices
population = [TeamName3+" Win", TeamName3 + ' dan ' + TeamName6 + ' seri', TeamName6+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match20 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName3,TeamName7))
from random import choices
population = [TeamName3+" Win", TeamName3 + ' dan ' + TeamName7 + ' seri', TeamName7+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match21 = choices(population, weights)


score = pd.Series(model.predict_proba(TeamName3,TeamName8))
from random import choices
population = [TeamName3+" Win", TeamName3 + ' dan ' + TeamName8 + ' seri', TeamName8+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match22 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName3,TeamName9))
from random import choices
population = [TeamName3+" Win", TeamName3 + ' dan ' + TeamName9 + ' seri', TeamName9+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match23 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName3,TeamName10))
from random import choices
population = [TeamName3+" Win", TeamName3 + ' dan ' + TeamName10 + ' seri', TeamName10+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match24 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName4,TeamName5))
from random import choices
population = [TeamName4+" Win", TeamName4 + ' dan ' + TeamName5 + ' seri', TeamName5+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match25 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName4,TeamName6))
from random import choices
population = [TeamName4+" Win", TeamName4 + ' dan ' + TeamName6 + ' seri', TeamName6+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match26 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName4,TeamName7))
from random import choices
population = [TeamName4+" Win", TeamName4 + ' dan ' + TeamName7 + ' seri', TeamName7+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match27 = choices(population, weights)


score = pd.Series(model.predict_proba(TeamName4,TeamName8))
from random import choices
population = [TeamName4+" Win", TeamName4 + ' dan ' + TeamName8 + ' seri', TeamName8+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match28 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName4,TeamName9))
from random import choices
population = [TeamName4+" Win", TeamName4 + ' dan ' + TeamName9 + ' seri', TeamName9+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match29 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName4,TeamName10))
from random import choices
population = [TeamName4+" Win", TeamName4 + ' dan ' + TeamName10 + ' seri', TeamName10+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match30 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName5,TeamName6))
from random import choices
population = [TeamName5+" Win", TeamName5 + ' dan ' + TeamName6 + ' seri', TeamName6+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match31 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName5,TeamName7))
from random import choices
population = [TeamName5+" Win", TeamName5 + ' dan ' + TeamName7 + ' seri', TeamName7+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match32 = choices(population, weights)


score = pd.Series(model.predict_proba(TeamName5,TeamName8))
from random import choices
population = [TeamName5+" Win", TeamName5 + ' dan ' + TeamName8 + ' seri', TeamName8+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match33 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName5,TeamName9))
from random import choices
population = [TeamName5+" Win", TeamName5 + ' dan ' + TeamName9 + ' seri', TeamName9+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match34 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName5,TeamName10))
from random import choices
population = [TeamName5+" Win", TeamName5 + ' dan ' + TeamName10 + ' seri', TeamName10+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match35 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName6,TeamName7))
from random import choices
population = [TeamName6+" Win", TeamName6 + ' dan ' + TeamName7 + ' seri', TeamName7+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match36 = choices(population, weights)


score = pd.Series(model.predict_proba(TeamName6,TeamName8))
from random import choices
population = [TeamName6+" Win", TeamName6 + ' dan ' + TeamName8 + ' seri', TeamName8+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match37 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName6,TeamName9))
from random import choices
population = [TeamName6+" Win", TeamName6 + ' dan ' + TeamName9 + ' seri', TeamName9+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match38 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName6,TeamName10))
from random import choices
population = [TeamName6+" Win", TeamName6 + ' dan ' + TeamName10 + ' seri', TeamName10+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match39 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName7,TeamName8))
from random import choices
population = [TeamName7+" Win", TeamName7 + ' dan ' + TeamName8 + ' seri', TeamName8+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match40 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName7,TeamName9))
from random import choices
population = [TeamName7+" Win", TeamName7 + ' dan ' + TeamName9 + ' seri', TeamName9+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match41 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName7,TeamName10))
from random import choices
population = [TeamName7+" Win", TeamName7 + ' dan ' + TeamName10 + ' seri', TeamName10+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match42 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName8,TeamName9))
from random import choices
population = [TeamName8+" Win", TeamName8 + ' dan ' + TeamName9 + ' seri', TeamName9+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match43 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName8,TeamName10))
from random import choices
population = [TeamName8+" Win", TeamName8 + ' dan ' + TeamName10 + ' seri', TeamName10+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match44 = choices(population, weights)

score = pd.Series(model.predict_proba(TeamName9,TeamName10))
from random import choices
population = [TeamName9+" Win", TeamName9 + ' dan ' + TeamName10 + ' seri', TeamName10+" Win"]
weights = [round(score[0], 4)*100, round(score[1], 4)*100, round(score[2], 4)*100]
match45 = choices(population, weights)

print(match1)
print(match2)
print(match3)
print(match4)
print(match5)
print(match6)
print(match7)
print(match8)
print(match9)
print(match10)
print(match11)
print(match12)
print(match13)
print(match14)
print(match15)
print(match16)
print(match17)
print(match18)
print(match19)
print(match20)
print(match21)
print(match22)
print(match23)
print(match24)
print(match25)
print(match26)
print(match27)
print(match28)
print(match29)
print(match30)
print(match31)
print(match32)
print(match33)
print(match34)
print(match35)
print(match36)
print(match37)
print(match38)
print(match39)
print(match40)
print(match41)
print(match42)
print(match43)
print(match44)
print(match45)


shortlist = [(match1),
             (match2),
             (match3),
             (match4),
             (match5),
             (match6),
             (match7),
             (match8),
             (match9),
             (match10),
             (match11),
             (match12),
             (match13),
             (match14),
             (match15),
             (match16),
             (match17),
             (match18),
             (match19),
             (match20),
             (match21),
             (match22),
             (match23),
             (match24),
             (match25),
             (match26),
             (match27),
             (match28),
             (match29),
             (match30),
             (match31),
             (match32),
             (match33),
             (match34),
             (match35),
             (match36),
             (match37),
             (match38),
             (match39),
             (match40),
             (match41),
             (match42),
             (match43),
             (match44),
             (match45)]

win1 = shortlist.count([TeamName1+" Win"])
print("Jumlah Kemenangan " + TeamName1 + " adalah " + str(win1))

win2 = shortlist.count([TeamName2+" Win"])
print("Jumlah Kemenangan " + TeamName2 + " adalah " + str(win2))

win3 = shortlist.count([TeamName3+" Win"])
print("Jumlah Kemenangan " + TeamName3 + " adalah " + str(win3))

win4 = shortlist.count([TeamName4+" Win"])
print("Jumlah Kemenangan " + TeamName4 + " adalah " + str(win4))

win5 = shortlist.count([TeamName5+" Win"])
print("Jumlah Kemenangan " + TeamName5 + " adalah " + str(win5))

win6 = shortlist.count([TeamName6+" Win"])
print("Jumlah Kemenangan " + TeamName6 + " adalah " + str(win6))

win7 = shortlist.count([TeamName7+" Win"])
print("Jumlah Kemenangan " + TeamName7 + " adalah " + str(win7))

win8 = shortlist.count([TeamName8+" Win"])
print("Jumlah Kemenangan " + TeamName8 + " adalah " + str(win8))

win9 = shortlist.count([TeamName9+" Win"])
print("Jumlah Kemenangan " + TeamName9 + " adalah " + str(win9))

win10 = shortlist.count([TeamName10+" Win"])
print("Jumlah Kemenangan " + TeamName10 + " adalah " + str(win10))
